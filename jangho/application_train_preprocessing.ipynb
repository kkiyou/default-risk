# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

default_path = "../lab10/raw_data/"
app_train = pd.read_csv(default_path+"application_train.csv")
# app_train = pd.read_csv('raw_data/application_train.csv')

# %%
app_train_df = pd.DataFrame(app_train)
app_train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307511 entries, 0 to 307510
# Columns: 122 entries, SK_ID_CURR to AMT_REQ_CREDIT_BUREAU_YEAR
# dtypes: float64(65), int64(41), object(16)
# memory usage: 286.2+ MB

# %%
df = app_train_df.set_index('SK_ID_CURR')
df.head()
# Out:
#             TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# SK_ID_CURR
# 100002           1         Cash loans           M            N
# 100003           0         Cash loans           F            N
# 100004           0    Revolving loans           M            Y
# 100006           0         Cash loans           F            N
# 100007           0         Cash loans           M            N
#
#            FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# SK_ID_CURR
# 100002                   Y             0          202500.0    406597.5
# 100003                   N             0          270000.0   1293502.5
# 100004                   Y             0           67500.0    135000.0
# 100006                   Y             0          135000.0    312682.5
# 100007                   Y             0          121500.0    513000.0
#
#             AMT_ANNUITY  AMT_GOODS_PRICE  ... FLAG_DOCUMENT_18  \
# SK_ID_CURR                                ...
# ...

# %%
df1 = df.iloc[:,9:19]
df2 = df.iloc[:,49:59]
df3 = df.iloc[:,89:99]
df4 = df.iloc[:,120:]

# %%
df_concat = pd.concat([df1, df2, df3, df4],axis=1, join='inner')
df_concat
# Out:
#             AMT_GOODS_PRICE NAME_TYPE_SUITE      NAME_INCOME_TYPE  \
# SK_ID_CURR
# 100002             351000.0   Unaccompanied               Working
# 100003            1129500.0          Family         State servant
# 100004             135000.0   Unaccompanied               Working
# 100006             297000.0   Unaccompanied               Working
# 100007             513000.0   Unaccompanied               Working
# ...                     ...             ...                   ...
# 456251             225000.0   Unaccompanied               Working
# 456252             225000.0   Unaccompanied             Pensioner
# 456253             585000.0   Unaccompanied               Working
# 456254             319500.0   Unaccompanied  Commercial associate
# 456255             675000.0   Unaccompanied  Commercial associate
#
#                       NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  \
# SK_ID_CURR
# 100002      Secondary / secondary special  Single / not married
# ...

# %%
df_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 307511 entries, 100002 to 456255
# Data columns (total 31 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   AMT_GOODS_PRICE             307233 non-null  float64
#  1   NAME_TYPE_SUITE             306219 non-null  object
#  2   NAME_INCOME_TYPE            307511 non-null  object
#  3   NAME_EDUCATION_TYPE         307511 non-null  object
#  4   NAME_FAMILY_STATUS          307511 non-null  object
#  5   NAME_HOUSING_TYPE           307511 non-null  object
#  6   REGION_POPULATION_RELATIVE  307511 non-null  float64
#  7   DAYS_BIRTH                  307511 non-null  int64
#  8   DAYS_EMPLOYED               307511 non-null  int64
#  9   DAYS_REGISTRATION           307511 non-null  float64
#  10  ENTRANCES_AVG               152683 non-null  float64
#  11  FLOORSMAX_AVG               154491 non-null  float64
# ...

# %%
df_concat.describe()
# Out:
#        AMT_GOODS_PRICE  REGION_POPULATION_RELATIVE     DAYS_BIRTH  \
# count     3.072330e+05               307511.000000  307511.000000
# mean      5.383962e+05                    0.020868  -16036.995067
# std       3.694465e+05                    0.013831    4363.988632
# min       4.050000e+04                    0.000290  -25229.000000
# 25%       2.385000e+05                    0.010006  -19682.000000
# 50%       4.500000e+05                    0.018850  -15750.000000
# 75%       6.795000e+05                    0.028663  -12413.000000
# max       4.050000e+06                    0.072508   -7489.000000
#
#        DAYS_EMPLOYED  DAYS_REGISTRATION  ENTRANCES_AVG  FLOORSMAX_AVG  \
# count  307511.000000      307511.000000  152683.000000  154491.000000
# mean    63815.045904       -4986.120328       0.149725       0.226282
# std    141275.766519        3522.886321       0.100049       0.144641
# min    -17912.000000      -24672.000000       0.000000       0.000000
# ...

# %%
df_concat.describe(include=np.object)
# Out:
#        NAME_TYPE_SUITE NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# count           306219           307511                         307511
# unique               7                8                              5
# top      Unaccompanied          Working  Secondary / secondary special
# freq            248526           158774                         218391
#
#        NAME_FAMILY_STATUS  NAME_HOUSING_TYPE EMERGENCYSTATE_MODE
# count              307511             307511              161756
# unique                  6                  6                   2
# top               Married  House / apartment                  No
# freq               196432             272868              159428

# %%
print(df_concat.NAME_TYPE_SUITE.value_counts())
print(df_concat.EMERGENCYSTATE_MODE.value_counts())
# Out:
# Unaccompanied      248526
# Family              40149
# Spouse, partner     11370
# Children             3267
# Other_B              1770
# Other_A               866
# Group of people       271
# Name: NAME_TYPE_SUITE, dtype: int64
# No     159428
# Yes      2328
# Name: EMERGENCYSTATE_MODE, dtype: int64

# %%
# #   Column                      Non-Null Count   Dtype      결측치처리
---  ------                      --------------   -----  
 0   AMT_GOODS_PRICE             307233 non-null  float64     mean   # scale변환 필요 Outlier: median로 대체
 1   NAME_TYPE_SUITE             306219 non-null  object      Unaccompanied  # 최빈값으로 대체          
 2   NAME_INCOME_TYPE            307511 non-null  object       
 3   NAME_EDUCATION_TYPE         307511 non-null  object       
 4   NAME_FAMILY_STATUS          307511 non-null  object       
 5   NAME_HOUSING_TYPE           307511 non-null  object       
 6   REGION_POPULATION_RELATIVE  307511 non-null  float64     
 7   DAYS_BIRTH                  307511 non-null  int64     
 8   DAYS_EMPLOYED               307511 non-null  int64       
 9   DAYS_REGISTRATION           307511 non-null  float64     
 10  ENTRANCES_AVG               152683 non-null  float64       0  
 11  FLOORSMAX_AVG               154491 non-null  float64       0
 12  FLOORSMIN_AVG               98869 non-null   float64       0
 13  LANDAREA_AVG                124921 non-null  float64       0
 14  LIVINGAPARTMENTS_AVG        97312 non-null   float64       0
 15  LIVINGAREA_AVG              153161 non-null  float64       0
 16  NONLIVINGAPARTMENTS_AVG     93997 non-null   float64       0
 17  NONLIVINGAREA_AVG           137829 non-null  float64       0
 18  APARTMENTS_MODE             151450 non-null  float64       0
 19  BASEMENTAREA_MODE           127568 non-null  float64       0
 20  EMERGENCYSTATE_MODE         161756 non-null  object        No   # 최빈값으로 대체
 21  OBS_30_CNT_SOCIAL_CIRCLE    306490 non-null  float64       0    # o or mean
 22  DEF_30_CNT_SOCIAL_CIRCLE    306490 non-null  float64       0
 23  OBS_60_CNT_SOCIAL_CIRCLE    306490 non-null  float64       0
 24  DEF_60_CNT_SOCIAL_CIRCLE    306490 non-null  float64       0
 25  DAYS_LAST_PHONE_CHANGE      307510 non-null  float64       0
 26  FLAG_DOCUMENT_2             307511 non-null  int64    
 27  FLAG_DOCUMENT_3             307511 non-null  int64  
 28  FLAG_DOCUMENT_4             307511 non-null  int64  
 29  FLAG_DOCUMENT_5             307511 non-null  int64  
 30  AMT_REQ_CREDIT_BUREAU_YEAR  265992 non-null  float64       0

# %%
df_concat['AMT_REQ_CREDIT_BUREAU_YEAR'].value_counts()
# Out:
# 0.0     71801
# 1.0     63405
# 2.0     50192
# 3.0     33628
# 4.0     20714
# 5.0     12052
# 6.0      6967
# 7.0      3869
# 8.0      2127
# 9.0      1096
# 11.0       31
# 12.0       30
# 10.0       22
# 13.0       19
# 14.0       10
# 17.0        7
# 15.0        6
# 19.0        4
# 18.0        4
# 16.0        3
# 21.0        1
# 23.0        1
# 25.0        1
# 20.0        1
# 22.0        1
# Name: AMT_REQ_CREDIT_BUREAU_YEAR, dtype: int64

# %%
# Null 처리
df_concat['AMT_GOODS_PRICE'].fillna(df_concat['AMT_GOODS_PRICE'].mean(), inplace = True)
df_concat['NAME_TYPE_SUITE'].fillna('Unaccompanied', inplace = True)
df_concat['EMERGENCYSTATE_MODE'].fillna('No', inplace = True)
df_concat['AMT_REQ_CREDIT_BUREAU_YEAR'].fillna(0, inplace = True)
df_concat.fillna(0, inplace=True)

# %%
df_concat.isnull().sum()
# Out:
# AMT_GOODS_PRICE               0
# NAME_TYPE_SUITE               0
# NAME_INCOME_TYPE              0
# NAME_EDUCATION_TYPE           0
# NAME_FAMILY_STATUS            0
# NAME_HOUSING_TYPE             0
# REGION_POPULATION_RELATIVE    0
# DAYS_BIRTH                    0
# DAYS_EMPLOYED                 0
# DAYS_REGISTRATION             0
# ENTRANCES_AVG                 0
# FLOORSMAX_AVG                 0
# FLOORSMIN_AVG                 0
# LANDAREA_AVG                  0
# LIVINGAPARTMENTS_AVG          0
# LIVINGAREA_AVG                0
# NONLIVINGAPARTMENTS_AVG       0
# NONLIVINGAREA_AVG             0
# APARTMENTS_MODE               0
# BASEMENTAREA_MODE             0
# EMERGENCYSTATE_MODE           0
# OBS_30_CNT_SOCIAL_CIRCLE      0
# DEF_30_CNT_SOCIAL_CIRCLE      0
# OBS_60_CNT_SOCIAL_CIRCLE      0
# DEF_60_CNT_SOCIAL_CIRCLE      0
# DAYS_LAST_PHONE_CHANGE        0
# FLAG_DOCUMENT_2               0
# FLAG_DOCUMENT_3               0
# FLAG_DOCUMENT_4               0
# ...

# %%
import matplotlib.pyplot as plt
plt.hist(df_concat['AMT_GOODS_PRICE'])
plt.show()

# %%
df_concat['TARGET'] = df['TARGET']

# %%
corr = df_concat.corr()
corr
# Out:
#                             AMT_GOODS_PRICE  REGION_POPULATION_RELATIVE  \
# AMT_GOODS_PRICE                    1.000000                    0.103482
# REGION_POPULATION_RELATIVE         0.103482                    1.000000
# DAYS_BIRTH                        -0.053416                   -0.029582
# DAYS_EMPLOYED                     -0.064826                   -0.003980
# DAYS_REGISTRATION                  0.011561                   -0.053820
# ENTRANCES_AVG                      0.054462                    0.099885
# FLOORSMAX_AVG                      0.099874                    0.250842
# FLOORSMIN_AVG                      0.067652                    0.216642
# LANDAREA_AVG                       0.033057                    0.018774
# LIVINGAPARTMENTS_AVG               0.057935                    0.174017
# LIVINGAREA_AVG                     0.080443                    0.196812
# NONLIVINGAPARTMENTS_AVG            0.015692                    0.034105
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(corr, cmap='RdBu')
# Out:
# <AxesSubplot:>

# %%
f, axes = plt.subplots(ncols=2, figsize=(15,8))

sns.boxplot(x="TARGET", y="AMT_GOODS_PRICE", data=df_concat, ax=axes[0])
axes[0].set_title('AMT_GOODS_PRICE vs TARGET')

sns.boxplot(x="TARGET", y="AMT_REQ_CREDIT_BUREAU_YEAR", data=df_concat, ax=axes[1])
axes[1].set_title('AMT_REQ_CREDIT_BUREAU_YEAR vs TARGET')
# Out:
# Text(0.5, 1.0, 'AMT_REQ_CREDIT_BUREAU_YEAR vs TARGET')

# %%
# IQR을 이용한 Outlier median 대체
def replace_outlier_by_med(feature) :
    q1, q3 = np.percentile(feature, [25, 75])
    iqr = q3 - q1
    lower_bound = q1 - (iqr*1.5)
    upper_bound = q3 + (iqr*1.5)
    
    mask = np.where((feature > upper_bound) | (feature < lower_bound),feature.median(), feature)
    return mask

# %%
df_concat['AMT_GOODS_PRICE'] = replace_outlier_by_med(df_concat['AMT_GOODS_PRICE'])

# %%
df_concat['AMT_GOODS_PRICE'].describe()
# Out:
# count    3.075110e+05
# mean     4.852615e+05
# std      2.835114e+05
# min      4.050000e+04
# 25%      2.385000e+05
# 50%      4.500000e+05
# 75%      6.750000e+05
# max      1.341000e+06
# Name: AMT_GOODS_PRICE, dtype: float64

# %%
plt.hist(df_concat['AMT_GOODS_PRICE'])
plt.show()

# %%
# IQR을 이용한 Outlier 찾기 (행 위치 반환)
def find_outlier_by_IQR(data) :
    q1, q3 = np.percentile(data, [25, 75])
    iqr = q3 - q1
    lower_bound = q1 - (iqr*1.5)
    upper_bound = q3 + (iqr*1.5)
    
    mask = np.where((data > upper_bound) | (data < lower_bound))
    return mask

# %%
mask = find_outlier_by_IQR(df_concat['AMT_GOODS_PRICE'])[0]
df_concat.iloc[mask]
# Out:
#             AMT_GOODS_PRICE NAME_TYPE_SUITE      NAME_INCOME_TYPE  \
# SK_ID_CURR
# 100009            1395000.0   Unaccompanied  Commercial associate
# 100010            1530000.0   Unaccompanied         State servant
# 100055            1350000.0   Unaccompanied         State servant
# 100056            1350000.0   Unaccompanied               Working
# 100071            1588500.0          Family  Commercial associate
# ...                     ...             ...                   ...
# 456155            1800000.0          Family             Pensioner
# 456191            1350000.0   Unaccompanied               Working
# 456216            1575000.0   Unaccompanied               Working
# 456220            1350000.0   Unaccompanied         State servant
# 456236            1575000.0   Unaccompanied               Working
#
#                       NAME_EDUCATION_TYPE NAME_FAMILY_STATUS  \
# SK_ID_CURR
# 100009                   Higher education            Married
# ...
