# %%
import pandas as pd

analisis=pd.read_csv('../data/analisis.csv')

# %%
# 분석 방향

# Train Target중 연체자 비율
# 현금/리볼빙 대출 타입에 따른 연체자 비율
# 성별에 따른 연체자 비율
# 차 소유 여부에 따른 연체자 비율 
# 집/아파트 보유 여부에 따른 연체자 비율
# 자녀수에 따른 연체자 비율
# 가족 수에 따른 연체자 비율
# 대출총액/수입
# 대출총액에 따른 연체자 비율
# AMT_GOODS_PRICE
# 
len(list(analisis.columns))
# Out:
# 87

# %%
print(len(analisis[(analisis['train/test'] == 'train')]))
print(len(analisis[(analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 0)]))
print(len(analisis[(analisis['train/test'] == 'train') & \
        (analisis['TARGET'] == 1)]))
# Out:
# 303953
# 279468
# 24485

# %%
# 데이터 시각화
import matplotlib.pyplot as plt

# %%
# Train Target중 연체자 비율

import matplotlib.pyplot as plt

ratio = [ (len(analisis[(analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)])/len(analisis[(analisis['train/test']=='train')]))*100, \
          (len(analisis[(analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 0)])/len(analisis[(analisis['train/test']=='train')]))*100  ]
labels = [ 'Unpaid','Paid',]
explode = [0.05, 0.05,]
colors = [ '#ff9999', 'whitesmoke']
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

#colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0']

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode, shadow=True, colors=colors)
plt.show()

# %% [markdown]
# ---------
# # 현금/리볼빙 대출 타입에 따른 연체자 비율

# %%
# 현금/리볼빙 대출 타입에 따른 연체자 비율
# Cash loans / Unpaid
print('Cash loans / Unpaid : ',len(analisis[(analisis['NAME_CONTRACT_TYPE'] == 'Cash loans') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)]))
# Revolving loans / Unpaid
print('Revolving loans / Unpaid : ',len(analisis[(analisis['NAME_CONTRACT_TYPE'] == 'Revolving loans') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)]))



ratio = [ (len(analisis[(analisis['NAME_CONTRACT_TYPE'] == 'Cash loans') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)]) / len(analisis[(analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)]))*100, \
         
          (len(analisis[(analisis['NAME_CONTRACT_TYPE'] == 'Revolving loans') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)]) /  len(analisis[(analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)]))*100]
labels = [ 'Cash loans','Revolving loans',]
explode = [0.05, 0.05,]
colors = [  'gold', '#ff9999',]
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

#colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0']

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode, shadow=True, colors=colors)
plt.show()
# Out:
# Cash loans / Unpaid :  22940
# Revolving loans / Unpaid :  1545

# %%
analisis['NAME_CONTRACT_TYPE'].unique()
# Out:
# array(['Cash loans', 'Revolving loans'], dtype=object)

# %%
# 전체(연체자/미연체자)중  현금/리볼빙 비율
#  Own Car/ Unpaid
print('Cash loans/ Unpaid : ',len(analisis[(analisis['NAME_CONTRACT_TYPE'] == 'Cash loans') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)]))
# Revolving loans/ Unpaid
print('Revolving loans/ Unpaid : ',len(analisis[(analisis['NAME_CONTRACT_TYPE'] == 'Revolving loans') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)]))
# Own Car/ paid
print('Cash loans/ paid : ',len(analisis[(analisis['NAME_CONTRACT_TYPE'] == 'Cash loans') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 0)]))
# Revolving loans/ paid
print('Revolving loans/ paid: ',len(analisis[(analisis['NAME_CONTRACT_TYPE'] == 'Revolving loans') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 0)]))


ratio = [ (len(analisis[(analisis['NAME_CONTRACT_TYPE'] == 'Cash loans') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)]) / len(analisis[(analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)+(analisis['TARGET'] == 0)]))*100, \
         
          (len(analisis[(analisis['NAME_CONTRACT_TYPE'] == 'Revolving loans') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)]) / len(analisis[(analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)+(analisis['TARGET'] == 0)]))*100, \
         
        (len(analisis[(analisis['NAME_CONTRACT_TYPE'] == 'Cash loans') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 0)]) / len(analisis[(analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 0)+(analisis['TARGET'] == 1)]))*100, \
         
        (len(analisis[(analisis['NAME_CONTRACT_TYPE'] == 'Revolving loans') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 0)]) / len(analisis[(analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 0)+(analisis['TARGET'] == 1)]))*100  ]

labels = [ 'Cash loans/Unpaid','Revolving loans/Unpaid','Cash loans/paid','Revolving loans/paid']
explode = [0.05, 0.05,0.05,0.05]
colors = [ '#ff9999', 'gold','#8fd9b6', '#d395d0']
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

#colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0']

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode, shadow=True, colors=colors)
plt.show()
# Out:
# Cash loans/ Unpaid :  22940
# Revolving loans/ Unpaid :  1545
# Cash loans/ paid :  252679
# Revolving loans/ paid:  26789
# C:\Users\pc\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:204: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead
#   warnings.warn(
# C:\Users\pc\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:204: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead
#   warnings.warn(
# C:\Users\pc\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:204: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead
#   warnings.warn(
# ...

# %% [markdown]
# -----------
# # 성별에 따른 연체자 비율

# %%
analisis['CODE_GENDER'].unique()
# Out:
# array(['M', 'F', 'XNA'], dtype=object)

# %%
len(analisis[(analisis['CODE_GENDER'] == 'XNA') & (analisis['train/test'] == 'train') ])
# Out:
# 4

# %%
len(analisis[(analisis['CODE_GENDER'] == 'XNA') & (analisis['train/test'] == 'test') ])
# Out:
# 0

# %%
# 남/여 따른 연체자 비율
# Cash loans / Unpaid
print('Cash loans / Unpaid : ',len(analisis[(analisis['CODE_GENDER'] == 'M') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET']==1)]))
# Revolving loans / Unpaid
print(len(analisis[(analisis['CODE_GENDER'] == 'F') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET']==1)]))



ratio = [ (len(analisis[(analisis['CODE_GENDER'] == 'M') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET']==1)])/ len(analisis[(analisis['train/test'] == 'train')& \
        (analisis['TARGET']==1)]))*100, \
          (len(analisis[(analisis['CODE_GENDER'] == 'F') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET']==1)])/ len(analisis[(analisis['train/test'] == 'train')& \
        (analisis['TARGET']==1)]))*100]
labels = [ 'Male','Female',]
explode = [0.05, 0.05,]
colors = [  'gold', '#ff9999',]
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

#colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0']

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode, shadow=True, colors=colors)
plt.show()
# Out:
# 10485
# 14000

# %%
# 남/여 따른 연체자 비율
# Male / Unpaid
print(len(analisis[(analisis['CODE_GENDER'] == 'M') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET']==1)]))
# Female / Unpaid
print(len(analisis[(analisis['CODE_GENDER'] == 'F') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET']==1)]))

# Male / paid
print(len(analisis[(analisis['CODE_GENDER'] == 'M') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET']==0)]))
# Female / paid
print(len(analisis[(analisis['CODE_GENDER'] == 'F') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET']==0)]))


ratio = [ (len(analisis[(analisis['CODE_GENDER'] == 'M') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)]) / len(analisis[(analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)+(analisis['TARGET'] == 0)]))*100, \
         
          (len(analisis[(analisis['CODE_GENDER'] == 'F') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)]) / len(analisis[(analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)+(analisis['TARGET'] == 0)]))*100, \
         
        (len(analisis[(analisis['CODE_GENDER'] == 'M') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 0)]) / len(analisis[(analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 0)+(analisis['TARGET'] == 1)]))*100, \
         
        (len(analisis[(analisis['CODE_GENDER'] == 'F') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 0)]) / len(analisis[(analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 0)+(analisis['TARGET'] == 1)]))*100  ]

labels = [ 'Male/Unpaid','Female/Unpaid','Male/paid','Female/paid']
explode = [0.05, 0.05,0.05,0.05]
colors = [ '#ff9999', 'gold','#8fd9b6', '#d395d0']
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

#colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0']

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode, shadow=True, colors=colors)
plt.show()
# Out:
# 10485
# 14000
# 93072
# 186392
# C:\Users\pc\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:204: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead
#   warnings.warn(
# C:\Users\pc\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:204: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead
#   warnings.warn(
# C:\Users\pc\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:204: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead
#   warnings.warn(
# C:\Users\pc\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:204: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead
#   warnings.warn(

# %% [markdown]
# ------------
# # 차 소유에 따른 따른 연체자 비율

# %%
# 차 소유에 따른 따른 연체자 비율
# Own Car/ Unpaid
print(len(analisis[(analisis['FLAG_OWN_CAR'] == 'Y') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET']==1)]))
# Non Own Car/ Unpaid
print(len(analisis[(analisis['FLAG_OWN_CAR'] == 'N') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET']==1)]))



ratio = [ (len(analisis[(analisis['FLAG_OWN_CAR'] == 'Y') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET']==1)])/ len(analisis[(analisis['train/test'] == 'train')& \
        (analisis['TARGET']==1)]))*100, \
          (len(analisis[(analisis['FLAG_OWN_CAR'] == 'N') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET']==1)])/ len(analisis[(analisis['train/test'] == 'train')& \
        (analisis['TARGET']==1)]))*100]
labels = [ 'Own Car','Non Own Car',]
explode = [0.05, 0.05,]
colors = [ '#ff9999', 'gold']
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

#colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0']

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode, shadow=True, colors=colors)
plt.show()
# Out:
# 7505
# 16980

# %%
# 전체(연체자/미연체자)중  차 소유/미소유
#  Own Car/ Unpaid
print(len(analisis[(analisis['FLAG_OWN_CAR'] == 'Y') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET']==1)]))
# Non Own Car/ Unpaid
print(len(analisis[(analisis['FLAG_OWN_CAR'] == 'N') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET']==1)]))
# Own Car/ paid
print(len(analisis[(analisis['FLAG_OWN_CAR'] == 'Y') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET']==0)]))
# Non Own Car/ paid
print(len(analisis[(analisis['FLAG_OWN_CAR'] == 'N') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET']==0)]))


ratio = [ (len(analisis[(analisis['FLAG_OWN_CAR'] == 'Y') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)]) / len(analisis[(analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)+(analisis['TARGET'] == 0)]))*100, \
         
          (len(analisis[(analisis['FLAG_OWN_CAR'] == 'N') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)]) / len(analisis[(analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)+(analisis['TARGET'] == 0)]))*100, \
         
        (len(analisis[(analisis['FLAG_OWN_CAR'] == 'Y') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 0)]) / len(analisis[(analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 0)+(analisis['TARGET'] == 1)]))*100, \
         
        (len(analisis[(analisis['FLAG_OWN_CAR'] == 'N') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 0)]) / len(analisis[(analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 0)+(analisis['TARGET'] == 1)]))*100  ]

labels = [ 'Own Car/Unpaid','Non Own Car/Unpaid','Non Own Car/paid','Non Own Car/paid']
explode = [0.05, 0.05,0.05,0.05]
colors = [ '#ff9999', 'gold','#8fd9b6', '#d395d0']
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

#colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0']

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode, shadow=True, colors=colors)
plt.show()
# Out:
# 7505
# 16980
# 95985
# 183483
# C:\Users\pc\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:204: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead
#   warnings.warn(
# C:\Users\pc\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:204: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead
#   warnings.warn(
# C:\Users\pc\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:204: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead
#   warnings.warn(
# C:\Users\pc\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:204: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead
#   warnings.warn(

# %% [markdown]
# -------------------
# #  FLAG_OWN_REALTY

# %%
analisis['FLAG_OWN_REALTY'].unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %%
# Realty 소유에 따른 따른 연체자 비율
# Own Realty/ Unpaid
print('Own Realty/Unpaid : ',len(analisis[(analisis['FLAG_OWN_REALTY'] == 'Y') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET']==1)]))
# Non Own Realty/ Unpaid
print('Non-Own Realty/Unpaid : ',len(analisis[(analisis['FLAG_OWN_REALTY'] == 'N') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET']==1)]))



ratio = [ (len(analisis[(analisis['FLAG_OWN_REALTY'] == 'Y') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET']==1)])/ len(analisis[(analisis['train/test'] == 'train')& \
        (analisis['TARGET']==1)]))*100, \
          (len(analisis[(analisis['FLAG_OWN_REALTY'] == 'N') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET']==1)])/ len(analisis[(analisis['train/test'] == 'train')& \
        (analisis['TARGET']==1)]))*100]
labels = [ 'Own Realty','Non Own Realty',]
explode = [0.05, 0.05,]
colors = [ '#ff9999', 'gold']
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

#colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0']

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode, shadow=True, colors=colors)
plt.show()
# Out:
# Own Realty/Unpaid :  16748
# Non-Own Realty/Unpaid :  7737

# %%
# 전체(연체자/미연체자)중  Realty주거지 소유/미소유
#  Own Realty/ Unpaid
print('Own Realty/ Unpaid : ',len(analisis[(analisis['FLAG_OWN_REALTY'] == 'Y') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET']==1)]))
# Non Own Realty/ Unpaid
print('Non-Own Realty/ Unpaid : ',len(analisis[(analisis['FLAG_OWN_REALTY'] == 'N') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET']==1)]))
# Own Realty/ paid
print('Own Realty/ paid : ',len(analisis[(analisis['FLAG_OWN_REALTY'] == 'Y') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET']==0)]))
# Non Own Realty/ paid
print('Non-Own Realty/ paid : ',len(analisis[(analisis['FLAG_OWN_REALTY'] == 'N') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET']==0)]))


ratio = [ (len(analisis[(analisis['FLAG_OWN_REALTY'] == 'Y') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)]) / len(analisis[(analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)+(analisis['TARGET'] == 0)]))*100, \
         
          (len(analisis[(analisis['FLAG_OWN_REALTY'] == 'N') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)]) / len(analisis[(analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)+(analisis['TARGET'] == 0)]))*100, \
         
        (len(analisis[(analisis['FLAG_OWN_REALTY'] == 'Y') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 0)]) / len(analisis[(analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 0)+(analisis['TARGET'] == 1)]))*100, \
         
        (len(analisis[(analisis['FLAG_OWN_REALTY'] == 'N') & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 0)]) / len(analisis[(analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 0)+(analisis['TARGET'] == 1)]))*100  ]

labels = [ 'Own Realty/Unpaid','Non Own Realty/Unpaid','Non Own Realty/paid','Non Own Realty/paid']
explode = [0.05, 0.05,0.05,0.05]
colors = [ '#ff9999', 'gold','#8fd9b6', '#d395d0']
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

#colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0']

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode, shadow=True, colors=colors)
plt.show()
# Out:
# Own Realty/ Unpaid :  16748
# Non-Own Realty/ Unpaid :  7737
# Own Realty/ paid :  194176
# Non-Own Realty/ paid :  85292
# C:\Users\pc\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:204: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead
#   warnings.warn(
# C:\Users\pc\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:204: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead
#   warnings.warn(
# C:\Users\pc\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:204: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead
#   warnings.warn(
# ...

# %% [markdown]
# ---------------
# # CNT_CHILDREN

# %%
analisis['CNT_CHILDREN'].unique()
# Out:
# array([0, 1, 2, 3, 4, 5], dtype=int64)

# %%
# 자녀 존재 여부에 따른 따른 연체자 비율
# CNT_CHILDREN/ Unpaid
print(len(analisis[(analisis['CNT_CHILDREN'] > 0 ) & (analisis['train/test'] == 'train')& \
        (analisis['TARGET']==1)]))
# Non CNT_CHILDREN/ Unpaid
print(len(analisis[(analisis['CNT_CHILDREN'] == 0 ) & (analisis['train/test'] == 'train')& \
        (analisis['TARGET']==1)]))



ratio = [ (len(analisis[(analisis['CNT_CHILDREN'] > 0) & (analisis['train/test'] == 'train')& \
        (analisis['TARGET']==1)])/ len(analisis[(analisis['train/test'] == 'train')& \
        (analisis['TARGET']==1)]))*100, \
          (len(analisis[(analisis['CNT_CHILDREN'] == 0) & (analisis['train/test'] == 'train')& \
        (analisis['TARGET']==1)])/ len(analisis[(analisis['train/test'] == 'train')& \
        (analisis['TARGET']==1)]))*100]
labels = [ 'Own CHILDREN','Non Own CHILDREN',]
explode = [0.05, 0.05,]
colors = [ '#ff9999', 'gold']
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

#colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0']

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode, shadow=True, colors=colors)
plt.show()
# Out:
# 8129
# 16356

# %%
# 자녀 수에 따른 따른 연체자 비율
# CNT_CHILDREN/ Unpaid
print(len(analisis[(analisis['CNT_CHILDREN'] == 5) & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)]))
# CNT_CHILDREN/ Unpaid
print(len(analisis[(analisis['CNT_CHILDREN'] == 4 ) & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)]))
# CNT_CHILDREN/ Unpaid
print(len(analisis[(analisis['CNT_CHILDREN'] == 3  ) & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)]))
# CNT_CHILDREN/ Unpaid
print(len(analisis[(analisis['CNT_CHILDREN'] == 2  ) & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)]))
# CNT_CHILDREN/ Unpaid
print(len(analisis[(analisis['CNT_CHILDREN'] == 1  ) & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)]))
# Non CNT_CHILDREN/ Unpaid
print(len(analisis[(analisis['CNT_CHILDREN'] == 0 ) & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)]))



ratio = [(len(analisis[(analisis['CNT_CHILDREN'] == 5) & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)])/ len(analisis[(analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)]))*100, \
    
        (len(analisis[(analisis['CNT_CHILDREN'] == 4) & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)])/ len(analisis[(analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)]))*100, \
    
        (len(analisis[(analisis['CNT_CHILDREN'] == 3) & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)])/ len(analisis[(analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)]))*100, \
         
        (len(analisis[(analisis['CNT_CHILDREN'] == 2) & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)])/ len(analisis[(analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)]))*100, \
         
        (len(analisis[(analisis['CNT_CHILDREN'] == 1) & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)])/ len(analisis[(analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)]))*100, \
         
          (len(analisis[(analisis['CNT_CHILDREN'] == 0) & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)])/ len(analisis[(analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)]))*100]
labels = [ '5 CHILD','4 CHILD','3 CHILD','2 CHILD','1 CHILD','Non CHILDREN',]
explode = [0.05, 0.05,0.05,0.05,0.05,0.05,]
colors = [ '#ff9999', 'gold', '#ffc000', '#8fd9b6', '#d395d0' ]
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

#colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0']

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode, shadow=True, colors=colors)
plt.show()
# Out:
# 16
# 55
# 356
# 2313
# 5389
# 16356

# %%
# 자녀 존재 여부에 따른 전체 비율
# CNT_CHILDREN/ Unpaid
print('CHILDREN/ Unpaid : ',len(analisis[(analisis['CNT_CHILDREN'] > 0 ) & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)]))
# Non CNT_CHILDREN/ Unpaid
print('Non_CHILDREN/ Unpaid : ',len(analisis[(analisis['CNT_CHILDREN'] == 0 ) & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)]))
# CNT_CHILDREN/ paid
print('CHILDREN/ paid : ',len(analisis[(analisis['CNT_CHILDREN'] > 0 ) & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 0)]))
# Non CNT_CHILDREN / paid
print('Non_CHILDREN/ paid : ',len(analisis[(analisis['CNT_CHILDREN'] == 0 ) & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 0)]))



ratio = [ (len(analisis[(analisis['CNT_CHILDREN'] > 0 ) & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)]) / len(analisis[(analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)+(analisis['TARGET'] == 0)]))*100, \
         
          (len(analisis[(analisis['CNT_CHILDREN'] == 0 ) & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)]) / len(analisis[(analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 1)+(analisis['TARGET'] == 0)]))*100, \
         
        (len(analisis[(analisis['CNT_CHILDREN'] > 0 ) & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 0)]) / len(analisis[(analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 0)+(analisis['TARGET'] == 1)]))*100, \
         
        (len(analisis[(analisis['CNT_CHILDREN'] == 0 ) & (analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 0)]) / len(analisis[(analisis['train/test'] == 'train')& \
        (analisis['TARGET'] == 0)+(analisis['TARGET'] == 1)]))*100  ]

labels = [ 'Children/Unpaid','Non Children/Unpaid','Children/paid','Non Children/paid']
explode = [0.05, 0.05,0.05,0.05]
colors = [ '#ff9999', 'gold','#8fd9b6', '#d395d0']
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

#colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0']

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode, shadow=True, colors=colors)
plt.show()
# Out:
# CHILDREN/ Unpaid :  8129
# Non_CHILDREN/ Unpaid :  16356
# CHILDREN/ paid :  83247
# Non_CHILDREN/ paid :  196221
# C:\Users\pc\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:204: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead
#   warnings.warn(
# C:\Users\pc\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:204: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead
#   warnings.warn(
# C:\Users\pc\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:204: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead
#   warnings.warn(
# ...

# %% [markdown]
# ------------
# # AMT_INCOME_TOTAL

# %%
# 소득에 따라 연체자 비율

# %%
analisis['AMT_INCOME_TOTAL'].describe()
# Out:
# count    3.523940e+05
# mean     1.696527e+05
# std      1.090681e+05
# min      2.565000e+04
# 25%      1.125000e+05
# 50%      1.530000e+05
# 75%      2.025000e+05
# max      1.800009e+07
# Name: AMT_INCOME_TOTAL, dtype: float64

# %%
# 소득에 따라 연체자 비율
# CNT_CHILDREN/ Unpaid

# CNT_CHILDREN/ Unpaid
print('AMT_INCOME_TOTAL > 200000 : ',len(analisis[(analisis['AMT_INCOME_TOTAL'] > 200000   ) & \
                   (analisis['train/test'] == 'train')& (analisis['TARGET'] == 1)]))
# CNT_CHILDREN/ Unpaid
print('AMT_INCOME_TOTAL > 150000 : ',len(analisis[(analisis['AMT_INCOME_TOTAL'] > 150000   ) & (analisis['AMT_INCOME_TOTAL'] < 200000   ) & \
                   (analisis['train/test'] == 'train')& (analisis['TARGET'] == 1)]))
# CNT_CHILDREN/ Unpaid
print('AMT_INCOME_TOTAL > 100000 : ',len(analisis[(analisis['AMT_INCOME_TOTAL'] > 100000   ) & (analisis['AMT_INCOME_TOTAL'] < 150000  ) & \
                   (analisis['train/test'] == 'train')& (analisis['TARGET'] == 1)]))
# CNT_CHILDREN/ Unpaid
print('AMT_INCOME_TOTAL < 100000 : ',len(analisis[(analisis['AMT_INCOME_TOTAL'] < 100000   ) & \
                   (analisis['train/test'] == 'train')& (analisis['TARGET'] == 1)])) 




ratio = [(len(analisis[(analisis['AMT_INCOME_TOTAL'] < 100000  ) & \
                      (analisis['train/test'] == 'train') & (analisis['TARGET'] == 1)]) / \
         len(analisis[(analisis['train/test'] == 'train') & (analisis['TARGET'] == 1)]))*100, \
    
        (len(analisis[(analisis['AMT_INCOME_TOTAL'] > 100000   ) & (analisis['AMT_INCOME_TOTAL']  < 150000  ) & \
                      (analisis['train/test'] == 'train') & (analisis['TARGET'] == 1)]) / \
         len(analisis[(analisis['train/test'] == 'train') & (analisis['TARGET'] == 1)]))*100, \
         
        (len(analisis[(analisis['AMT_INCOME_TOTAL']  > 150000  ) & (analisis['AMT_INCOME_TOTAL'] < 200000  ) & \
                      (analisis['train/test'] == 'train') & (analisis['TARGET'] == 1)]) / \
         len(analisis[(analisis['train/test'] == 'train') & (analisis['TARGET'] == 1)]))*100, \
         
         
        (len(analisis[(analisis['AMT_INCOME_TOTAL']  > 200000  ) & \
                      (analisis['train/test'] == 'train') & (analisis['TARGET'] == 1)]) / \
         len(analisis[(analisis['train/test'] == 'train') & (analisis['TARGET'] == 1)]))*100  ]
         
         
labels = [ 'INCOME < 100000','INCOME > 100000','INCOME > 150000','INCOME> 200000']
explode = [0.05, 0.05,0.05,0.05,]
colors = [ '#ff9999', 'gold', '#ffc000', '#8fd9b6', ]
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

#colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0']

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode, shadow=True, colors=colors)
plt.show()
# Out:
# AMT_INCOME_TOTAL > 200000 :  6221
# AMT_INCOME_TOTAL > 150000 :  5364
# AMT_INCOME_TOTAL > 100000 :  7777
# AMT_INCOME_TOTAL < 100000 :  5123

# %%
6221+5364+7777+  5123
# Out:
# 24485

# %% [markdown]
# -----
# # AMT_CREDIT

# %%
analisis['AMT_CREDIT'].describe()
# 25000 50000 75000
# Out:
# count    3.523940e+05
# mean     5.871392e+05
# std      3.972859e+05
# min      4.500000e+04
# 25%      2.700000e+05
# 50%      5.002110e+05
# 75%      7.941735e+05
# max      4.050000e+06
# Name: AMT_CREDIT, dtype: float64

# %%
# 대출에 따른 연체자 비율

# CNT_CHILDREN/ Unpaid
print('AMT_CREDIT > 750000 : ',len(analisis[(analisis['AMT_CREDIT'] > 750000   ) & \
                   (analisis['train/test'] == 'train')& (analisis['TARGET'] == 1)]))
# CNT_CHILDREN/ Unpaid
print('AMT_CREDIT > 500000 : ',len(analisis[(analisis['AMT_CREDIT'] > 500000   ) & (analisis['AMT_ANNUITY'] < 750000  ) & \
                   (analisis['train/test'] == 'train')& (analisis['TARGET'] == 1)]))
# CNT_CHILDREN/ Unpaid
print('AMT_CREDIT > 250000 : ',len(analisis[(analisis['AMT_CREDIT'] > 250000   ) & (analisis['AMT_ANNUITY'] < 500000  ) & \
                   (analisis['train/test'] == 'train')& (analisis['TARGET'] == 1)]))
# CNT_CHILDREN/ Unpaid
print('AMT_CREDIT < 170000 : ',len(analisis[(analisis['AMT_CREDIT'] < 250000  ) & \
                   (analisis['train/test'] == 'train')& (analisis['TARGET'] == 1)])) 




ratio = [(len(analisis[(analisis['AMT_CREDIT'] > 750000  ) & \
                      (analisis['train/test'] == 'train') & (analisis['TARGET'] == 1)]) / \
         len(analisis[(analisis['train/test'] == 'train') & (analisis['TARGET'] == 1)]))*100, \
    
        (len(analisis[(analisis['AMT_CREDIT'] > 500000   ) & (analisis['AMT_ANNUITY']  < 750000  ) & \
                      (analisis['train/test'] == 'train') & (analisis['TARGET'] == 1)]) / \
         len(analisis[(analisis['train/test'] == 'train') & (analisis['TARGET'] == 1)]))*100, \
         
        (len(analisis[(analisis['AMT_CREDIT']  > 250000  ) & (analisis['AMT_ANNUITY'] < 500000  ) & \
                      (analisis['train/test'] == 'train') & (analisis['TARGET'] == 1)]) / \
         len(analisis[(analisis['train/test'] == 'train') & (analisis['TARGET'] == 1)]))*100, \
         
         
        (len(analisis[(analisis['AMT_CREDIT']  < 250000  ) & \
                      (analisis['train/test'] == 'train') & (analisis['TARGET'] == 1)]) / \
         len(analisis[(analisis['train/test'] == 'train') & (analisis['TARGET'] == 1)]))*100  ]
         
         
labels = [ 'AMT_CREDIT > 750000','AMT_CREDIT > 500000','AMT_CREDIT > 250000','AMT_CREDIT < 250000']
explode = [0.05, 0.05,0.05,0.05,]
colors = [ '#ff9999', 'gold', '#ffc000', '#8fd9b6', ]
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

#colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0']

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode, shadow=True, colors=colors)
plt.show()
# Out:
# AMT_CREDIT > 750000 :  5997
# AMT_CREDIT > 500000 :  12092
# AMT_CREDIT > 250000 :  20365
# AMT_CREDIT < 170000 :  4120

# %%
5997+ 12092+20365+ 4120
# Out:
# 42574

# %% [markdown]
# ----
# #  AMT_ANNUITY

# %%
analisis['AMT_ANNUITY'].describe()
# Out:
# count    352394.000000
# mean      27401.832642
# std       14648.956604
# min        1615.500000
# 25%       16753.500000
# 50%       25083.000000
# 75%       34956.000000
# max      258025.500000
# Name: AMT_ANNUITY, dtype: float64

# %%
# 17000 27000 37000

# %%
# 대출에 따른 연체자 비율

# CNT_CHILDREN/ Unpaid
print('AMT_ANNUITY > 37000 : ',len(analisis[(analisis['AMT_ANNUITY'] > 37000   ) & \
                   (analisis['train/test'] == 'train')& (analisis['TARGET'] == 1)]))
# CNT_CHILDREN/ Unpaid
print('AMT_ANNUITY > 27000 : ',len(analisis[(analisis['AMT_ANNUITY'] > 27000   ) & (analisis['AMT_ANNUITY'] < 37000  ) & \
                   (analisis['train/test'] == 'train')& (analisis['TARGET'] == 1)]))
# CNT_CHILDREN/ Unpaid
print('AMT_ANNUITY > 17000 : ',len(analisis[(analisis['AMT_ANNUITY'] > 17000   ) & (analisis['AMT_ANNUITY'] < 27000  ) & \
                   (analisis['train/test'] == 'train')& (analisis['TARGET'] == 1)]))
# CNT_CHILDREN/ Unpaid
print('AMT_ANNUITY < 17000 : ',len(analisis[(analisis['AMT_ANNUITY'] < 17000  ) & \
                   (analisis['train/test'] == 'train')& (analisis['TARGET'] == 1)])) 




ratio = [(len(analisis[(analisis['AMT_ANNUITY'] > 37000  ) & \
                      (analisis['train/test'] == 'train') & (analisis['TARGET'] == 1)]) / \
         len(analisis[(analisis['train/test'] == 'train') & (analisis['TARGET'] == 1)]))*100, \
    
        (len(analisis[(analisis['AMT_ANNUITY'] > 27000   ) & (analisis['AMT_ANNUITY']  < 37000  ) & \
                      (analisis['train/test'] == 'train') & (analisis['TARGET'] == 1)]) / \
         len(analisis[(analisis['train/test'] == 'train') & (analisis['TARGET'] == 1)]))*100, \
         
        (len(analisis[(analisis['AMT_ANNUITY']  > 17000  ) & (analisis['AMT_ANNUITY'] < 27000  ) & \
                      (analisis['train/test'] == 'train') & (analisis['TARGET'] == 1)]) / \
         len(analisis[(analisis['train/test'] == 'train') & (analisis['TARGET'] == 1)]))*100, \
         
         
        (len(analisis[(analisis['AMT_ANNUITY']  < 17000  ) & \
                      (analisis['train/test'] == 'train') & (analisis['TARGET'] == 1)]) / \
         len(analisis[(analisis['train/test'] == 'train') & (analisis['TARGET'] == 1)]))*100  ]
         
         
labels = [ 'AMT_ANNUITY < 17000','AMT_ANNUITY > 17000','AMT_ANNUITY > 27000','AMT_ANNUITY > 37000']
explode = [0.05, 0.05,0.05,0.05,]
colors = [ '#ff9999', 'gold', '#ffc000', '#8fd9b6', ]
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

#colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0']

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode, shadow=True, colors=colors)
plt.show()
# Out:
# AMT_ANNUITY > 37000 :  4215
# AMT_ANNUITY > 27000 :  6162
# AMT_ANNUITY > 17000 :  8331
# AMT_ANNUITY < 17000 :  5760

# %%
4215+ 6162+ 8331+5760
# Out:
# 24468
